# %%
import numpy as np 
import pandas as pd 
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
X = data.data 
y = data.target

# %%
df = pd.DataFrame(data.data  , columns = data.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
from sklearn.model_selection import train_test_split 

X_train , X_test , y_train , y_test = train_test_split(X, y, test_size = 0.2 , random_state = 2)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
model = lr.fit(X_train , y_train)

pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

print(f"Accuracy for the model : {accuracy_score(pred, y_test)}")
print(f"Confusion matrix for the model : {confusion_matrix(pred, y_test)}")
# Out:
# Accuracy for the model : 0.9666666666666667
# Confusion matrix for the model : [[14  0  0]
#  [ 0  7  0]
#  [ 0  1  8]]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Confusion matrix for Iris dataset")
# Out:
# Text(0.5, 1.0, 'Confusion matrix for Iris dataset')
