# %%
from dotenv import load_dotenv
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI

from typing import TypedDict

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    google_api_key="GEMINI_API_KEY"
)

# %%
class llm_state(TypedDict):
    question : str
    answer : str

# %%
def llm_qa(state : llm_state):
    question = state['question']

    prompt = f'Answer the follow question {question}'

    answer = model.invoke(prompt).content

    state['answer'] = answer
    return state

# %%
# creting the graph 
graph = StateGraph(llm_state)

# nodes 
graph.add_node('llm_qa', llm_qa)

# edges 
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile 
workflow = graph.compile()
# Out:
# c:\Users\ganam\AppData\Local\Programs\Python\Python310\lib\site-packages\langgraph\graph\state.py:99: UserWarning: Invalid state_schema: <function llm_state at 0x000002B565EB4940>. Expected a type or Annotated[type, reducer]. Please provide a valid schema to ensure correct updates.
#  See: https://langchain-ai.github.io/langgraph/reference/graphs/#stategraph
#   warnings.warn(

# %%
initial_state = {
    "question": "Who is the prime minister of Iran?",
    "answer": ""
}

final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       1 initial_state = {
#       2     "question": "Who is the prime minister of Iran?",
#       3     "answer": ""
#       4 }
# ----> 6 final_state = workflow.invoke(initial_state)
#       8 print(final_state['answer'])
#
# File c:\Users\ganam\AppData\Local\Programs\Python\Python310\lib\site-packages\langgraph\pregel\main.py:3094, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3091 chunks: list[dict[str, Any] | Any] = []
#    3092 interrupts: list[Interrupt] = []
# -> 3094 for chunk in self.stream(
#    3095     input,
#    3096     config,
#    3097     context=context,
#    3098     stream_mode=["updates", "values"]
#    3099     if stream_mode == "values"
#    3100     else stream_mode,
#    3101     print_mode=print_mode,
#    3102     output_keys=output_keys,
#    3103     interrupt_before=interrupt_before,
#    3104     interrupt_after=interrupt_after,
#    3105     durability=durability,
#    3106     **kwargs,
#    3107 ):
#    3108     if stream_mode == "values":
#    3109         if len(chunk) == 2:
#
# File c:\Users\ganam\AppData\Local\Programs\Python\Python310\lib\site-packages\langgraph\pregel\main.py:2666, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2659             return waiter
#    2661 # Similarly to Bulk Synchronous Parallel / Pregel model
#    2662 # computation proceeds in steps, while there are channel updates.
#    2663 # Channel updates from step N are only visible in step N+1
#    2664 # channels are guaranteed to be immutable for the duration of the step,
#    2665 # with channel updates applied only at the transition between steps.
# -> 2666 while loop.tick():
#    2667     for task in loop.match_cached_writes():
#    2668         loop.output_writes(task.id, task.writes, cached=True)
#
# File c:\Users\ganam\AppData\Local\Programs\Python\Python310\lib\site-packages\langgraph\pregel\_loop.py:472, in PregelLoop.tick(self)
#     469     return False
#     471 # prepare next tasks
# --> 472 self.tasks = prepare_next_tasks(
#     473     self.checkpoint,
#     474     self.checkpoint_pending_writes,
#     475     self.nodes,
#     476     self.channels,
#     477     self.managed,
#     478     self.config,
#     479     self.step,
#     480     self.stop,
#     481     for_execution=True,
#     482     manager=self.manager,
#     483     store=self.store,
#     484     checkpointer=self.checkpointer,
#     485     trigger_to_nodes=self.trigger_to_nodes,
#     486     updated_channels=self.updated_channels,
#     487     retry_policy=self.retry_policy,
#     488     cache_policy=self.cache_policy,
#     489 )
#     491 # produce debug output
#     492 if self._checkpointer_put_after_previous is not None:
#
# File c:\Users\ganam\AppData\Local\Programs\Python\Python310\lib\site-packages\langgraph\pregel\_algo.py:468, in prepare_next_tasks(checkpoint, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, trigger_to_nodes, updated_channels, retry_policy, cache_policy)
#     465 # Check if any processes should be run in next step
#     466 # If so, prepare the values to be passed to them
#     467 for name in candidate_nodes:
# --> 468     if task := prepare_single_task(
#     469         (PULL, name),
#     470         None,
#     471         checkpoint=checkpoint,
#     472         checkpoint_id_bytes=checkpoint_id_bytes,
#     473         checkpoint_null_version=null_version,
#     474         pending_writes=pending_writes,
#     475         processes=processes,
#     476         channels=channels,
#     477         managed=managed,
#     478         config=config,
#     479         step=step,
#     480         stop=stop,
#     481         for_execution=for_execution,
#     482         store=store,
#     483         checkpointer=checkpointer,
#     484         manager=manager,
#     485         input_cache=input_cache,
#     486         cache_policy=cache_policy,
#     487         retry_policy=retry_policy,
#     488     ):
#     489         tasks.append(task)
#     490 return {t.id: t for t in tasks}
#
# File c:\Users\ganam\AppData\Local\Programs\Python\Python310\lib\site-packages\langgraph\pregel\_algo.py:614, in prepare_single_task(task_path, task_id_checksum, checkpoint, checkpoint_id_bytes, checkpoint_null_version, pending_writes, processes, channels, managed, config, step, stop, for_execution, store, checkpointer, manager, input_cache, cache_policy, retry_policy)
#     612 # create task input
#     613 try:
# --> 614     val = _proc_input(
#     615         proc,
#     616         managed,
#     617         channels,
#     618         for_execution=for_execution,
#     619         input_cache=input_cache,
#     620         scratchpad=scratchpad,
#     621     )
#     622     if val is MISSING:
#     623         return
#
# File c:\Users\ganam\AppData\Local\Programs\Python\Python310\lib\site-packages\langgraph\pregel\_algo.py:1159, in _proc_input(proc, managed, channels, for_execution, scratchpad, input_cache)
#    1157 # If the process has a mapper, apply it to the value
#    1158 if for_execution and proc.mapper is not None:
# -> 1159     val = proc.mapper(val)
#    1161 # Cache the input value
#    1162 if input_cache is not None:
#
# File c:\Users\ganam\AppData\Local\Programs\Python\Python310\lib\site-packages\langgraph\graph\state.py:1513, in _coerce_state(schema, input)
#    1512 def _coerce_state(schema: type[Any], input: dict[str, Any]) -> dict[str, Any]:
# -> 1513     return schema(**input)
#
# TypeError: llm_state() missing 1 required positional argument: 'state'
